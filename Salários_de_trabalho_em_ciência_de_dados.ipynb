# %% [markdown]
# <a href="https://colab.research.google.com/github/tiago1811/Exame-do-Ensino-M-dio-do-Vietn-2017-a-2021/blob/main/Sal%C3%A1rios_de_trabalho_em_ci%C3%AAncia_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aluno**: Tiago de Melo Monteiro

# %% [markdown]
# # Contexto:

# %% [markdown]
# A ciência de dados é um campo interdisciplinar que usa métodos, processos, algoritmos e sistemas científicos para extrair conhecimento e insights de dados ruidosos, estruturados e não estruturados e aplicar o conhecimento de dados em uma ampla variedade de domínios de aplicativos. A ciência de dados é uma carreira muito boa, com enormes oportunidades de avanço no futuro. A demanda já é alta, os salários são competitivos e as vantagens são inúmeras – e é por isso que o Data Scientist foi chamado de “a carreira mais promissora” pelo LinkedIn e o “melhor emprego da América” pela Glassdoor. O salário médio de um cientista de dados é de Rs. 698.412 por ano. Com menos de um ano de experiência, um cientista de dados de nível básico pode ganhar aproximadamente 500.000 por ano. Os cientistas de dados com 1 a 4 anos de experiência podem esperar ganhar cerca de 610.811 por ano.

# %% [markdown]
# # Começo do código em Python:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
salario=pd.read_csv('https://raw.githubusercontent.com/tiago1811/Sal-rios-de-trabalho-em-ci-ncia-de-dados/main/ds_salaries.csv')

# %%
salario
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# **Salário:**	O valor total do salário bruto pago.
# **Salário em usd:**	O salário em USD (taxa de câmbio dividida pela taxa média em SD para o respectivo ano via fxdata.foorilla.com).
# **Proporção_remoto:**	A quantidade total de trabalho feito remotamente, os valores possíveis são os seguintes: Nenhum trabalho remoto (menos de 20%) 50 Parcialmente remoto 100 Totalmente remoto (mais de 80%)

# %%
salario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
salario.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# # graficos das variaveis:

# %%
salario['salary'].value_counts().head().plot.pie(autopct='%.0f%%')

# %%
salario['salary_in_usd'].value_counts().head().plot.pie(autopct='%.0f%%')

# %%
salario['remote_ratio'].value_counts().head().plot.pie(autopct='%.0f%%')

# %% [markdown]
# # cruzamentos das variaveis:

# %%
Cruzamentossalario = salario[['salary',	'salary_in_usd', 'remote_ratio']]
Cruzamentossalario
# Out:
#      salary  salary_in_usd  remote_ratio
# 0     70000          79833             0
# 1    260000         260000             0
# 2     85000         109024            50
# 3     20000          20000             0
# 4    150000         150000            50
# ..      ...            ...           ...
# 602  154000         154000           100
# 603  126000         126000           100
# 604  129000         129000             0
# 605  150000         150000           100
# 606  200000         200000           100
#
# [607 rows x 3 columns]
